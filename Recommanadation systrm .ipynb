# %%
import numpy as np
import pandas as pd

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
user = pd.read_csv(r"C:\Users\Yogesh\Downloads\User.csv")
movies = pd.read_csv(r"C:\Users\Yogesh\Downloads\Movies.csv")

# %%
user.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movies.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
user.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100003 entries, 0 to 100002
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   user_id    100003 non-null  int64
#  1   item_id    100003 non-null  int64
#  2   rating     100003 non-null  int64
#  3   timestamp  100003 non-null  int64
# dtypes: int64(4)
# memory usage: 3.1 MB

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1682 entries, 0 to 1681
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   item_id  1682 non-null   int64
#  1   title    1682 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 26.4+ KB

# %%
df = user.merge(movies)

# %%
df.drop("timestamp",axis=1,inplace=True)

# %%
df.head()
# Out:
#    user_id  item_id  rating                            title
# 0        0       50       5                 Star Wars (1977)
# 1        0      172       5  Empire Strikes Back, The (1980)
# 2        0      133       1        Gone with the Wind (1939)
# 3      196      242       3                     Kolya (1996)
# 4      186      302       3         L.A. Confidential (1997)

# %%
df.groupby("title")["rating"].mean().sort_values(ascending=False)
# Out:
# title
# Aiqing wansui (1994)                                 5.0
# Entertaining Angels: The Dorothy Day Story (1996)    5.0
# Santa with Muscles (1996)                            5.0
# Prefontaine (1997)                                   5.0
# They Made Me a Criminal (1939)                       5.0
#                                                     ...
# Pharaoh's Army (1995)                                1.0
# August (1996)                                        1.0
# Babyfever (1994)                                     1.0
# Amityville: A New Generation (1993)                  1.0
# Woman in Question, The (1950)                        1.0
# Name: rating, Length: 1664, dtype: float64

# %%
df.groupby("title")["rating"].mean().sort_values(ascending=False)
# Out:
# title
# Aiqing wansui (1994)                                 5.0
# Entertaining Angels: The Dorothy Day Story (1996)    5.0
# Santa with Muscles (1996)                            5.0
# Prefontaine (1997)                                   5.0
# They Made Me a Criminal (1939)                       5.0
#                                                     ...
# Pharaoh's Army (1995)                                1.0
# August (1996)                                        1.0
# Babyfever (1994)                                     1.0
# Amityville: A New Generation (1993)                  1.0
# Woman in Question, The (1950)                        1.0
# Name: rating, Length: 1664, dtype: float64

# %%
df.groupby("title")["rating"].mean().sort_values(ascending=False)
# Out:
# title
# Aiqing wansui (1994)                                 5.0
# Entertaining Angels: The Dorothy Day Story (1996)    5.0
# Santa with Muscles (1996)                            5.0
# Prefontaine (1997)                                   5.0
# They Made Me a Criminal (1939)                       5.0
#                                                     ...
# Pharaoh's Army (1995)                                1.0
# August (1996)                                        1.0
# Babyfever (1994)                                     1.0
# Amityville: A New Generation (1993)                  1.0
# Woman in Question, The (1950)                        1.0
# Name: rating, Length: 1664, dtype: float64

# %%
df["title"].value_counts()
# Out:
# title
# Star Wars (1977)                              584
# Contact (1997)                                509
# Fargo (1996)                                  508
# Return of the Jedi (1983)                     507
# Liar Liar (1997)                              485
#                                              ...
# Eighth Day, The (1996)                          1
# Mamma Roma (1962)                               1
# Scream of Stone (Schrei aus Stein) (1991)       1
# Getting Away With Murder (1996)                 1
# Nobody Loves Me (Keiner liebt mich) (1994)      1
# Name: count, Length: 1664, dtype: int64

# %%
(df["title"].value_counts()>100).index.tolist()
# Out:
# ['Star Wars (1977)',
#  'Contact (1997)',
#  'Fargo (1996)',
#  'Return of the Jedi (1983)',
#  'Liar Liar (1997)',
#  'English Patient, The (1996)',
#  'Scream (1996)',
#  'Toy Story (1995)',
#  'Air Force One (1997)',
#  'Independence Day (ID4) (1996)',
#  'Raiders of the Lost Ark (1981)',
#  'Godfather, The (1972)',
#  'Pulp Fiction (1994)',
#  'Twelve Monkeys (1995)',
#  'Silence of the Lambs, The (1991)',
#  'Jerry Maguire (1996)',
#  'Chasing Amy (1997)',
#  'Rock, The (1996)',
#  'Empire Strikes Back, The (1980)',
#  'Star Trek: First Contact (1996)',
#  'Titanic (1997)',
#  'Back to the Future (1985)',
#  'Mission: Impossible (1996)',
#  'Fugitive, The (1993)',
#  'Indiana Jones and the Last Crusade (1989)',
#  'Willy Wonka and the Chocolate Factory (1971)',
#  'Princess Bride, The (1987)',
#  'Forrest Gump (1994)',
#  'Monty Python and the Holy Grail (1974)',
#  'Saint, The (1997)',
#  'Full Monty, The (1997)',
#  'Men in Black (1997)',
#  'Terminator, The (1984)',
# ...

# %%
dummy = (df["title"].value_counts()>100).reset_index()

# %%
dummy
# Out:
#                                            title  count
# 0                               Star Wars (1977)   True
# 1                                 Contact (1997)   True
# 2                                   Fargo (1996)   True
# 3                      Return of the Jedi (1983)   True
# 4                               Liar Liar (1997)   True
# ...                                          ...    ...
# 1659                      Eighth Day, The (1996)  False
# 1660                           Mamma Roma (1962)  False
# 1661   Scream of Stone (Schrei aus Stein) (1991)  False
# 1662             Getting Away With Murder (1996)  False
# 1663  Nobody Loves Me (Keiner liebt mich) (1994)  False
#
# [1664 rows x 2 columns]

# %%
df =df[df["title"].isin(dummy[dummy["count"]==True]["title"])]

# %%
df.reset_index(inplace=True,drop=True)

# %%
df["title"].value_counts()
# Out:
# title
# Star Wars (1977)                   584
# Contact (1997)                     509
# Fargo (1996)                       508
# Return of the Jedi (1983)          507
# Liar Liar (1997)                   485
#                                   ...
# Young Guns (1988)                  101
# Sex, Lies, and Videotape (1989)    101
# Pinocchio (1940)                   101
# Miracle on 34th Street (1994)      101
# Mimic (1997)                       101
# Name: count, Length: 334, dtype: int64

# %%
df.groupby("title")["rating"].mean().sort_values(ascending=False)
# Out:
# title
# Close Shave, A (1995)               4.491071
# Schindler's List (1993)             4.466443
# Wrong Trousers, The (1993)          4.466102
# Casablanca (1942)                   4.456790
# Shawshank Redemption, The (1994)    4.445230
#                                       ...
# Spawn (1997)                        2.615385
# Event Horizon (1997)                2.574803
# Crash (1996)                        2.546875
# Jungle2Jungle (1997)                2.439394
# Cable Guy, The (1996)               2.339623
# Name: rating, Length: 334, dtype: float64

# %%
user_matrix = pd.pivot_table(df,columns="user_id", index="title",values="rating",fill_value=0)

# %%
df
# Out:
#        user_id  item_id  rating                            title
# 0            0       50       5                 Star Wars (1977)
# 1            0      172       5  Empire Strikes Back, The (1980)
# 2            0      133       1        Gone with the Wind (1939)
# 3          196      242       3                     Kolya (1996)
# 4          186      302       3         L.A. Confidential (1997)
# ...        ...      ...     ...                              ...
# 64606      913      209       2        This Is Spinal Tap (1984)
# 64607      880      476       3     First Wives Club, The (1996)
# 64608      716      204       5        Back to the Future (1985)
# 64609       13      225       2            101 Dalmatians (1996)
# 64610       12      203       3                Unforgiven (1992)
#
# [64611 rows x 4 columns]

# %%
user_corr =user_matrix.corr()

# %%
user_corr[0].sort_values(ascending=False).head(6)
# Out:
# user_id
# 0      1.000000
# 369    0.436268
# 51     0.381308
# 563    0.360060
# 723    0.349776
# 182    0.341624
# Name: 0, dtype: float64

# %%
movie_matrix = pd.pivot_table(df,index="user_id", columns="title",values="rating",fill_value=0)

# %%
movie_matrix
# Out:
# title    101 Dalmatians (1996)  12 Angry Men (1957)  \
# user_id
# 0                          0.0                  0.0
# 1                          2.0                  5.0
# 2                          0.0                  0.0
# 3                          0.0                  0.0
# 4                          0.0                  0.0
# ...                        ...                  ...
# 939                        0.0                  0.0
# 940                        0.0                  0.0
# 941                        0.0                  0.0
# 942                        0.0                  0.0
# 943                        0.0                  0.0
#
# title    2001: A Space Odyssey (1968)  Absolute Power (1997)  \
# user_id
# 0                                 0.0                    0.0
# 1                                 4.0                    0.0
# 2                                 0.0                    3.0
# 3                                 0.0                    0.0
# ...

# %%
movies_corr =  movie_matrix.corr()

# %%
movies_corr
# Out:
# title                                         101 Dalmatians (1996)  \
# title
# 101 Dalmatians (1996)                                      1.000000
# 12 Angry Men (1957)                                        0.059375
# 2001: A Space Odyssey (1968)                               0.078451
# Absolute Power (1997)                                      0.221130
# Abyss, The (1989)                                          0.121285
# ...                                                             ...
# Willy Wonka and the Chocolate Factory (1971)               0.311255
# Wizard of Oz, The (1939)                                   0.124808
# Wrong Trousers, The (1993)                                 0.074758
# Young Frankenstein (1974)                                  0.155599
# Young Guns (1988)                                          0.115300
#
# title                                         12 Angry Men (1957)  \
# title
# 101 Dalmatians (1996)                                    0.059375
# ...

# %%
movies_corr["Absolute Power (1997)"].sort_values(ascending=False).head(6).tail()
# Out:
# title
# Ransom (1996)                    0.415015
# Broken Arrow (1996)              0.404915
# Executive Decision (1996)        0.395066
# Independence Day (ID4) (1996)    0.369910
# Rock, The (1996)                 0.348154
# Name: Absolute Power (1997), dtype: float64

# %%
movies_corr["Star Wars (1977)"].sort_values(ascending=False).head(6).tail()
# Out:
# title
# Return of the Jedi (1983)                    0.746797
# Empire Strikes Back, The (1980)              0.555233
# Raiders of the Lost Ark (1981)               0.540455
# Indiana Jones and the Last Crusade (1989)    0.467523
# Toy Story (1995)                             0.456219
# Name: Star Wars (1977), dtype: float64
